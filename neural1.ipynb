# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import sys
print(sys.executable)
# Out:
# /Users/ashurastogi/Neural-Networks/.venv/bin/python
