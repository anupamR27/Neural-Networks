# %% [markdown]
# <a href="https://colab.research.google.com/github/anupamR27/Neural-Networks/blob/main/Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio

# %%
import torch
import numpy

# x = torch.tensor([[1,2,3]
                #  ,[4,5,6]]
                # )

# print(x.shape)
# print(x)
# y=x.view(6)
# print(y)
# print(y.shape)
# z = x.reshape(3,2)
# print(z)

# %%
x = torch.tensor(2.0 , requires_grad=True)
y = x ** 2
z = x** 3
print(y)
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
# y.backward()
z.backward()

# %%
print(x.grad)
# Out:
# tensor(12.)
