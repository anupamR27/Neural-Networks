# %%
# !pip install torch torchvision torchaudio

# %%
import torch
import numpy

# x = torch.tensor([[1,2,3]
                #  ,[4,5,6]]
                # )

# print(x.shape)
# print(x)
# y=x.view(6)
# print(y)
# print(y.shape)
# z = x.reshape(3,2)
# print(z)

# %%
# x = torch.tensor(2.0 , requires_grad=True)
# y = x ** 2
# z = x** 3
# print(y)
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
# y.backward()
# z.backward()

# %%
# print(x.grad)
# Out:
# tensor(12.)

# %%
x = torch.rand(3, requires_grad = True)
print(x)
# Out:
# tensor([0.9609, 0.9536, 0.2183], requires_grad=True)

# %%
y = x+2
print(y)
# Out:
# tensor([2.9609, 2.9536, 2.2183], grad_fn=<AddBackward0>)

# %%
z = y*y*2
print(z)

v= torch.tensor([1.0,2.0,3.0] , dtype=float)
# Out:
# tensor([17.5341, 17.4479,  9.8417], grad_fn=<MulBackward0>)

# %%
z.backward(v)
print(x.grad)
# Out:
# tensor([11.8437, 23.6290, 26.6196])
